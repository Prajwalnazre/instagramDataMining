# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
posts = pd.DataFrame()
posts = posts.assign(Date = ['02/05/21', '03/05/21', '05/05/21', '06/05/21', '20/05/21', '21/05/21', '22/05/21', '23/05/21', '27/05/21', '28/05/21', '16/06/21', '01/07/21', '02/07/21'])
posts = posts.assign(Likes = [373, 245, 222, 108, 169, 147, 167, 164, 152, 78, 186, 154, 159])
posts = posts.assign(NoOfSlides = [7, 7, 5, 1, 7, 7, 1, 6, 5, 1, 6, 3, 5])
posts = posts.assign(Comments = [48, 25, 30, 4, 31, 27, 12, 11, 14, 3, 52, 54, 52])
posts = posts.assign(Body = [True, True, True, False, True, True, False, True, True, False, True, True, True])
posts = posts.assign(TopColour = ['Pink', 'Black', 'Blue', 'NaN', 'Pink', 'White', 'NaN', 'Black', 'Black', 'NaN', 'Pink', 'Brown', 'Blue'])
posts = posts.assign(BottomColour = ['Yellow', 'Black', 'Blue', 'NaN', 'Green', 'Green', 'NaN', 'White', 'Blue', 'NaN', 'Pink', 'Black', 'Red'])
posts = posts.assign(AccessoryColour = ['Green', 'White', 'Pink', 'Green', 'Pink', 'Orange', 'NaN', 'Black', 'Blue', 'NaN', 'Orange', 'Black', 'Green'])
posts = posts.assign(Saves = [68, 14, 9, 12, 8, 10, 14, 4, 6, 5, 14, 2, 2])
posts = posts.assign(Promotion = [True, False, False, False, False, False, False, False, False, False, False, False, False])
posts = posts.assign(Goggles = [True, False, False, True, True, True, False, False, True, False, True, True, True])
# posts = posts.assign(Shares = [0, 0, 0])
posts
# Out:
#         Date  Likes  NoOfSlides  ...  Saves  Promotion Goggles
# 0   02/05/21    373           7  ...     68       True    True
# 1   03/05/21    245           7  ...     14      False   False
# 2   05/05/21    222           5  ...      9      False   False
# 3   06/05/21    108           1  ...     12      False    True
# 4   20/05/21    169           7  ...      8      False    True
# 5   21/05/21    147           7  ...     10      False    True
# 6   22/05/21    167           1  ...     14      False   False
# 7   23/05/21    164           6  ...      4      False   False
# 8   27/05/21    152           5  ...      6      False    True
# 9   28/05/21     78           1  ...      5      False   False
# 10  16/06/21    186           6  ...     14      False    True
# 11  01/07/21    154           3  ...      2      False    True
# 12  02/07/21    159           5  ...      2      False    True
#
# [13 rows x 11 columns]

# %%
unpromotedPosts = posts[posts['Promotion'] == False]
# print(unpromotedPosts)
x = unpromotedPosts['Date']
y = unpromotedPosts['Likes']
plt.plot(x, y)
plt.figure(figsize=(7, 7))
plt.show()
